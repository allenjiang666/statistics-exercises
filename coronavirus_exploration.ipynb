# %%
import pandas as pd

# %%
coronavirus = pd.read_csv('NUMBERS_data.csv')

# %%
coronavirus.sample(10)
# Out:
#       Cases Countries and territories       Date  Deaths Geo Id  \
# 3068      0                    France   2/7/2020       0     FR
# 3909      0                    Sweden  2/22/2020       0     SE
# 510       0                   Bahrain  2/19/2020       0     BH
# 5579     31                    Taiwan  3/19/2020       0     TW
# 5548      1                 Nicaragua  3/19/2020       0     NI
# 2257      0                     Spain  1/23/2020       0     ES
# 4271      1                    Monaco  2/29/2020       0     MC
# 4143      0                   Estonia  2/27/2020       0     EE
# 2240      2                  Thailand  1/22/2020       0     TH
# 2454      1                 Singapore  1/26/2020       0     SG
#
#       Total Conf Cases all
# 3068                     0
# 3909                     0
# 510                      0
# 5579                    31
# 5548                     1
# 2257                     0
# 4271                     1
# 4143                     0
# ...

# %%
coronavirus.reset_index?
